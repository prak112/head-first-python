# %% [markdown]
# - Total laps per swimmer not consistent, i.e., lap time must be iterated using `body` variable
# - Use `utils.normalize` to adjust lap time values (in millisecs) to be within svg width range (400)

# %%
import os
import swimclub
import webbrowser

CHARTS_PATH = "charts/"
if not os.path.exists(CHARTS_PATH):
  os.makedirs(CHARTS_PATH)

swimdata_files = os.listdir(swimclub.DataFile.DATA_DIR.value)
swimdata_files.remove('.DS_Store')
# for fname in swimdata_files:
fname = "Lizzie-14-100m-Back.txt"
save_to = swimclub.generate_bar_chart(fname)

# open last processed file in default system browser
webbrowser.open(f"file://{os.path.realpath(save_to)}")
# Out:
# True
