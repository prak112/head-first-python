# %%
from DBcm import UseDatabase, SQLError

db_details = "KuopioSwimmers.sqlite3"
QUERY = """
  SELECT time()
"""
with UseDatabase(config=db_details) as db:
  db.execute(QUERY)
  print(db.fetchall())
# Out:
# [('13:20:44',)]
